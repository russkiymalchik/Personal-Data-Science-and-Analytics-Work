# %% [markdown]
# ##Topic 3 - Python Structure & Data Type Assignment

# %% [markdown]
# # Data Type Declaration

# %% [markdown]
# 1. > Create an empty variable (Points : 5)

# %%
#Code goes here

empty = None
print(empty)
# Out:
# None

# %% [markdown]
# 2. > Create a variable containing your name (Points : 5)

# %%
#Code goes here

name = 'Khairi Wiryawan S'
print(name)
# Out:
# Khairi Wiryawan S

# %% [markdown]
# 3. > Create a list of 5 items you can find in the classroom (Points : 5)

# %%
#Code goes here
classroom = ['book','pencil','pen','paper','eraser']
print(classroom)
# Out:
# ['book', 'pencil', 'pen', 'paper', 'eraser']

# %% [markdown]
# 4. > Create a dictionary containing 2 keys and value (Points : 5)

# %%
#Code goes here

dict = {
  "name": "Khairi Wiryawan S",
  "nickname": "Kai",
  "year_of_birth": 2001
}
print(dict)
# Out:
# {'name': 'Khairi Wiryawan S', 'nickname': 'Kai', 'year_of_birth': 2001}

# %% [markdown]
# # Basic Data Operation

# %% [markdown]
# You sold 20 pieces of electronics at the price of 12000. The customer gets a total discount of 10%.
#
# Below are those variables:
#
# 1.   price=12000
# 2.   quantity_sold=20
# 3.   discount=10%
#
#
# Using Python code, write the code the find the total money that the customer to pay. (Points : 15)

# %%
#Code goes here
price=12000
quantity_sold=20
discount=10/100

total = (price*quantity_sold)*(1-discount)
print(total)
# Out:
# 216000.0

# %% [markdown]
# # List Data Operation

# %% [markdown]
# 5. > Follow the instructions in the code blocks

# %%
# Create list of countries in the world (total 7 countries) (Points : 5)

#Code goes here

countries = ['United States', 'France', 'United Kingdom', 'Russian federation', 'China', 'Canada', 'Germany']

# %%
# Get 4 countries from the first index of the list (Points : 5)

#Code goes here
print(countries[:4])
# Out:
# ['United States', 'France', 'United Kingdom', 'Russian federation']

# %%
# Append new country to the list (Points : 5)

#Code goes here
countries.append('Italy')
print(countries)
# Out:
# ['United States', 'France', 'United Kingdom', 'Russian federation', 'China', 'Canada', 'Germany', 'Italy']

# %%
# Drop one country from the list (Points : 5)

#Code goes here
countries.remove('Germany')
print(countries)
# Out:
# ['United States', 'France', 'United Kingdom', 'Russian federation', 'China', 'Canada', 'Italy']

# %%
# Get country in the last index (Points : 5)

#Code goes here
print(countries[-1])
# Out:
# Italy

# %% [markdown]
# # Dictionary Data Operation

# %% [markdown]
# 6. >  Follow the instructions below

# %%
# Given the dictionary below

customer={
    "name":['Dio','Eka','Wayu','Riki'],
    "age":[20,19,24,39],
    "gender":[1,0,0,1],
    "membership":['Platinum','Gold','Silver','Silver']
}

# %%
# Print all keys in customer (Points : 5)

#Code goes here
for key in customer.keys():
    print(key)
# Out:
# name
# age
# gender
# membership

# %%
# Print all customer names (Points : 5)

#Code goes here

print(customer['name'])
# Out:
# ['Dio', 'Eka', 'Wayu', 'Riki']

# %%
# Print the first customer name (Points : 5)

#Code goes here
print(customer['name'][0])
# Out:
# Dio

# %%
# Drop "age" key from the dictionary (Points : 5)

#Code goes here
del customer['age']

print(str(customer))
# Out:
# {'name': ['Dio', 'Eka', 'Wayu', 'Riki'], 'gender': [1, 0, 0, 1], 'membership': ['Platinum', 'Gold', 'Silver', 'Silver']}

# %%
# Replace customer gender list value (Points : 20)
# gender 1 => Male
# gender 0 => Female 

#Code goes here
for l in range(len(customer['gender'])):
    if customer['gender'][l]==1:
        customer['gender'][l]='Male'
        
    else : customer['gender'][l]='Female'
        
print(customer)
# Out:
# {'name': ['Dio', 'Eka', 'Wayu', 'Riki'], 'gender': ['Male', 'Female', 'Female', 'Male'], 'membership': ['Platinum', 'Gold', 'Silver', 'Silver']}
